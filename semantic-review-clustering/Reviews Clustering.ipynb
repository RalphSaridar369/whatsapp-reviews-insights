# %%
# !pip install numpy==1.26.4 --force-reinstall
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 102.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install umap-learn hdbscan

# %%
# !pip install fasttext-wheel --no-cache-dir
# !wget https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.ftz
# !pip install sentence-transformers
# !pip install chromadb
# !pip install hdbscan
# !pip install umap-learn
# !pip install bertopic

import os
import sys

print(os.getcwd())
sys.path.append("/content/drive/MyDrive/Colab_Notebooks/reviews_clustering_python_files")
print(os.getcwd())
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 290.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.2/314.2 kB 414.7 MB/s eta 0:00:00
# ...
# --2026-07-26 20:09:01--  https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.ftz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 65.9.168.81, 65.9.168.62, 65.9.168.52, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|65.9.168.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 938013 (916K) [binary/octet-stream]
# Saving to: ‘lid.176.ftz’
#
# lid.176.ftz         100%[===================>] 916.03K  --.-KB/s    in 0.008s
#
# 2026-07-26 20:09:01 (113 MB/s) - ‘lid.176.ftz’ saved [938013/938013]
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 87.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 26.4 MB/s eta 0:00:00
# ...

# %%
import os
import sys

sys.path.append("/content/drive/MyDrive/Colab_Notebooks/reviews_clustering_python_files")
print(os.getcwd())
# Out:
# /content

# %%
import importlib

import data_initialization
import preprocessing
import language_detection
import embedding
import database_handling
import clustering
import topic_modeling
import describe_cluster
import handle_xlsx

importlib.reload(data_initialization)
importlib.reload(preprocessing)
importlib.reload(language_detection)
importlib.reload(embedding)
importlib.reload(database_handling)
importlib.reload(clustering)
importlib.reload(topic_modeling)
importlib.reload(describe_cluster)
importlib.reload(handle_xlsx)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  438MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# ...

# %%
# 1 - Initializing DataFrame
from data_initialization import initDataFrame

df = initDataFrame()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Understand Dataset Architecture

print('🔝 Head\n')
df.head()
# Out:
# 🔝 Head
#                                reviewId          content  score
# 0  56a6cc75-5646-4d18-aff1-a8f4f77b3d30  this is amazing      5
# 1  4ac92861-f05f-4476-8ef5-117dfe5edd4d             ভালো      5
# 2  2aa97411-6ca5-4b9e-8cd2-8ba270159698             Good      5
# 3  a5145e24-e40e-49e1-b31c-b4c407985097             good      5
# 4  79c99c39-2042-419e-83ea-3071f5cff048          Santosg      5

# %%
print('💻 Info\n')
df.info()
# Out:
# 💻 Info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reviewId  10000 non-null  object
#  1   content   9999 non-null   object
#  2   score     10000 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 234.5+ KB

# %%
print('🛠 Columns\n')
df.columns
# Out:
# 🛠 Columns
# Index(['reviewId', 'content', 'score'], dtype='object')

# %% [markdown]
# ## Now have set the data. next step is to preprocess it:
#
#
# *   remove duplicates
# *   remove nullables
# *   remove useless columns

# %%
# 2 - Preprocessing
from preprocessing import preProcessDataset

df = preProcessDataset(df)

# %% [markdown]
# #### What comes next is language detection, I have later on noticed this while checking out the data. This dataset has multi-language reviews, and it makes sense to have that, thus this part must be handled by **storing an additional column: language** .

# %%
# 3 - Language Detection
from language_detection import applyLanguageDetection

df = applyLanguageDetection(df)

# %%
df.head()
# Out:
#                                reviewId  \
# 0  96be2c8a-77f9-4329-8d2d-dc251289436e
# 1  d20c93d0-fc01-4914-9c8d-5e8ae7956535
# 2  8b7c6c06-bf58-4af7-a50e-3082df3a6c77
# 3  157d0558-6fc7-43f0-8b95-cd734a92caf8
# 4  956a2095-37b8-48d6-ac9c-8163621362b1
#
#                                              content  score language
# 0                      great tool for communication!      5       en
# 1  WhatsApp error. That verification code is sent...      1       en
# 2  I really appreciate you WhatsApp messenger for...      5       en
# 3  WhatsApp update is very poor edit option gone ...      1       en
# 4   the app is very very poor it is a shame ooh meta      1       en

# %%
df["language"].value_counts()
# Out:
# language
# en     3699
# it       50
# id       29
# es       14
# de       12
# ar       10
# fa       10
# bn        9
# pt        8
# fr        7
# ms        6
# ja        6
# nl        6
# hi        5
# pl        4
# eu        4
# et        3
# ceb       3
# af        2
# ta        2
# fy        2
# sw        2
# cy        2
# sv        2
# tr        2
# eo        2
# no        2
# sh        1
# ga        1
# hu        1
# km        1
# ko        1
# hy        1
# cs        1
# si        1
# gd        1
# war       1
# la        1
# arz       1
# uz        1
# qu        1
# sr        1
# ur        1
# ru        1
# br        1
# oc        1
# el        1
# th        1
# zh        1
# bg        1
# jv        1
# Name: count, dtype: int64

# %% [markdown]
# ### Now we have to embed the data, specifically the **content** part of the review

# %%
# 4 - Embedding
from embedding import embedData

embeddings = embedData(df["content"])
# Out:
# Batches:   0%|          | 0/123 [00:00<?, ?it/s]

# %%
embeddings.shape
# Out:
# (3927, 768)

# %% [markdown]
# ### Time to store the data in the vectorDB

# %%
# 5 - Storing data in VectorDB
from database_handling import handleDatabase

handleDatabase(df, embeddings)
# Out:
# Inserted 3927 reviews.

# %% [markdown]
# ### Clustering

# %%
import numpy as np

print(embeddings.shape)
print(type(embeddings))

print(np.min(embeddings))
print(np.max(embeddings))
print(np.std(embeddings))

from sklearn.metrics.pairwise import cosine_similarity

print(cosine_similarity([embeddings[0]], [embeddings[1]]))
print(cosine_similarity([embeddings[0]], [embeddings[2]]))
# Out:
# (3927, 768)
# <class 'numpy.ndarray'>
# -0.21596138
# 0.21135108
# 0.036084387
# [[0.1212179]]
# [[0.3369093]]

# %%
# 6 - Cluster the data
from clustering import clusterData

umap_model, hdbscan_model, vectorizer_model, ctfidf_model = clusterData()

# %%
# 7 - Create topic model
from topic_modeling import createTopicModel

topic_model = createTopicModel(umap_model, hdbscan_model, vectorizer_model, ctfidf_model)

topics, _ = topic_model.fit_transform(df['content'].tolist(), embeddings)
df['cluster'] = topics
# Out:
# 2026-07-26 20:11:50,856 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-07-26 20:12:39,931 - BERTopic - Dimensionality - Completed ✓
# 2026-07-26 20:12:39,934 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2026-07-26 20:12:40,064 - BERTopic - Cluster - Completed ✓
# 2026-07-26 20:12:40,071 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2026-07-26 20:12:46,516 - BERTopic - Representation - Completed ✓

# %%
topic_info = topic_model.get_topic_info()   # Topic, Count, Name, Representation

# %%
topic_info
# Out:
#     Topic  Count                                               Name  \
# 0      -1    684                          -1_ads_code_whatapp_money
# 1       0    212                                   0_hai_ho_mera_ke
# 2       1    198                    1_express_share_ideas_messenger
# 3       2    178  2_connecting_makes communication_compare_photo...
# 4       3    159                  3_far_beautiful_honestly_breaking
# ..    ...    ...                                                ...
# 62     61     16      61_filters_bubble_expressive_experience happy
# 63     62     15              62_secured_trusted_security_free data
# 64     63     15                  63_names_inside_deleting_directly
# 65     64     15             64_delay_wp_happy service_lack network
# 66     65     15                                   65_que_la_en_los
#
#                                        Representation  \
# 0   [ads, code, whatapp, money, verified, aap, stu...
# ...

# %%
df[df['cluster'] == 1]
# Out:
#                                   reviewId  \
# 2     8b7c6c06-bf58-4af7-a50e-3082df3a6c77
# 8     7292fc85-7762-4b4b-ae5c-ad6a79556a23
# 18    842bcdd2-bc79-4ee4-b4f0-6f6e3deb5c2e
# 20    51bf9eb0-a77e-499d-9db1-959a2a91330b
# 51    2686ce99-a37c-4744-8428-9da40e838846
# ...                                    ...
# 3829  15a972e8-c9d4-43ab-a74e-afd0e8cc46a4
# 3830  7381dce2-072e-410b-ae52-0c79b566bfe3
# 3861  0cd70eb4-23bb-4cf4-add5-f6f407beb9d9
# 3883  d7d92f72-442c-46bd-8857-2796fefd9371
# 3924  8ac85cba-70dd-418b-a6c5-14a7fd5830d2
#
#                                                 content  score language  \
# 2     I really appreciate you WhatsApp messenger for...      5       en
# 8                                  WhatsApp is good app      5       en
# 18    i think whatsapp is the best communication in ...      5       en
# 20                     Whatsapp is good to me thanks 👍😊      3       en
# 51    excellent , great. this WhatsApp is good wonde...      5       en
# ...

# %%
topic_info[['Topic', 'Count']].sort_values('Count', ascending=False)
# Out:
#     Topic  Count
# 0      -1    684
# 1       0    212
# 2       1    198
# 3       2    178
# 4       3    159
# ..    ...    ...
# 61     60     16
# 63     62     15
# 64     63     15
# 65     64     15
# 66     65     15
#
# [67 rows x 2 columns]

# %%
# 8 - Describing each cluster
# !pip install openai -q

from openai import OpenAI
from describe_cluster import describeCluster


topic_info["description"] = topic_info["Topic"].apply(
    lambda topic_id: describeCluster(topic_model, topic_id)
)

# %%
avg_scores = df.groupby('cluster')['score'].mean()

topic_info['avg_score'] = topic_info['Topic'].map(avg_scores)

topic_info[['Topic', 'Count', 'avg_score', 'description']].sort_values('Count', ascending=False)
# Out:
#     Topic  Count  avg_score                                        description
# 0      -1    684   3.532164              Miscellaneous / no clear single theme
# 1       0    212   3.547170         Account access issues and app malfunctions
# 2       1    198   4.484848  Sharing information and communication features...
# 3       2    178   4.438202        User feedback on app features and usability
# 4       3    159   4.729560  Positive feedback about app performance and fe...
# ..    ...    ...        ...                                                ...
# 61     60     16   4.687500     Positive feedback and expressions of happiness
# 63     62     15   4.533333              App reliability and security features
# 64     63     15   2.666667  Issues with contact management and synchroniza...
# 65     64     15   1.400000               Network connectivity and call issues
# 66     65     15   2.800000  Issues with app functionality and feature requ...
#
# [67 rows x 4 columns]

# %%
df[df["cluster"] == 9]
# Out:
#                                   reviewId  \
# 27    6829b07a-10de-45a6-84c2-d62d9865775b
# 149   6b95fd71-e6cc-4119-97d2-c8aa475460de
# 250   efc5d78a-4c02-4602-af07-de7f3bd6aa13
# 262   a35048a6-f662-4500-b0d1-c8558f4e7fa0
# 353   37cbdc73-1b66-4342-9624-bb09ef45177f
# ...                                    ...
# 3482  b9d2c53d-8524-450c-9abc-eac8488a8c57
# 3486  a9a5b454-8cd0-4a65-878e-85645e2fa90a
# 3586  be04fc6b-fedc-4d43-9b21-bbbdcbddb17a
# 3625  685ba73c-a759-4c36-b650-23db310e90d4
# 3816  0f986322-74aa-4dba-87bc-ba8cdec16a06
#
#                                                 content  score language  \
# 27                         plz ofan my business account      5       en
# 149             Please let them stop banding my account      5       en
# 250   “I clicked a suspicious link unknowingly. I di...      5       en
# 262          My name is ifeyibobo I won't you to sub me      5       en
# 353                             Don activity my account      5       en
# ...

# %%
# 9 - Writing to XLSX
# !pip install openpyxl -q
from handle_xlsx import writeToXlsx

writeToXlsx(topic_info, df)
# Out:
# Saved to /content/drive/MyDrive/whatsapp_analysis/whatsapp_review_clusters_semantic.xlsx
